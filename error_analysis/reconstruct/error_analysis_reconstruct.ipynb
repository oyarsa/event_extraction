# %%
import json

import pandas as pd

# %%
from IPython.display import display, HTML


pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)

def pp(df):
    return display(HTML(df.to_html().replace("\\n","<br>")))

# %%
with open('predict_outputs.json') as f:
    predict_outputs = json.load(f)
    label_ids = pd.DataFrame.from_records(predict_outputs['label_ids'])
    predictions = pd.DataFrame.from_records(predict_outputs['predictions'])

pp(label_ids.head())
pp(predictions.head())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>answers</th>
#       <th>question_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>e4552669</td>
#       <td>BB&amp;T and SunTrust have completed their merger, forming Truist, which we believe will drive the next step up in profitability for the franchises</td>
#       <td>enable</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3c233dd1</td>
#       <td>Given Tulip's lack of profitability (management has stated the business was not profitable at the time of the October 2019 acquisition), we do not believe the business maintains a cost advantage</td>
#       <td>enable</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>70aee733</td>
# ...

# %%
df = pd.merge(label_ids, predictions, on='id')
diff = df.query('answers != prediction_text')
pp(diff.head())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>answers</th>
#       <th>question_type</th>
#       <th>prediction_text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>70aee733</td>
#       <td>TC Energy's profitability is not directly tied to commodity prices, because pipeline transportation costs are not tied to the price of natural gas and crude oil</td>
#       <td>cause</td>
#       <td>pipeline transportation costs are not tied to the price of natural gas and crude oil, TC Energy's profitability is not directly tied to commodity prices</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5671e953</td>
# ...

# %%
pp(diff.head(20))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>answers</th>
#       <th>question_type</th>
#       <th>prediction_text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>70aee733</td>
#       <td>TC Energy's profitability is not directly tied to commodity prices, because pipeline transportation costs are not tied to the price of natural gas and crude oil</td>
#       <td>cause</td>
#       <td>pipeline transportation costs are not tied to the price of natural gas and crude oil, TC Energy's profitability is not directly tied to commodity prices</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5671e953</td>
# ...
