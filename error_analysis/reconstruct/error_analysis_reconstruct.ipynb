# %%
import json

import pandas as pd

# %%
from IPython.display import display, HTML


pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)

def pp(df):
    return display(HTML(df.to_html().replace("\\n","<br>")))

# %%
with open('predict_outputs.json') as f:
    predict_outputs = json.load(f)
    label_ids = pd.DataFrame.from_records(predict_outputs['label_ids'])
    predictions = pd.DataFrame.from_records(predict_outputs['predictions'])

pp(label_ids.head())
pp(predictions.head())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>answers</th>
#       <th>question_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>81c8921e</td>
#       <td>BB&amp;T and SunTrust have completed their merger, forming Truist, which we believe will drive the next step up in profitability for the franchises</td>
#       <td>enable</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>69559a66</td>
#       <td>Given Tulip's lack of profitability (management has stated the business was not profitable at the time of the October 2019 acquisition), we do not believe the business maintains a cost advantage</td>
#       <td>enable</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>745a44f4</td>
#       <td>TC Energy's profitability is not directly tied to commodity prices, because pipeline transportation costs are not tied to the price of natural gas and crude oil</td>
#       <td>cause</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>824a897f</td>
#       <td>Wynn has recently renovated rooms and the gaming floor space at its peninsula property, which should help the facility maintain market share over the next few years</td>
#       <td>enable</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>63be7842</td>
#       <td>We are keeping our fair value estimate for Danaher at $160 per share after raising it in January 2021 to reflect recently generated cash flows and our higher near-term outlook primarily for its tools used to diagnose and develop products to treat COVID-19</td>
#       <td>cause</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>prediction_text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>81c8921e</td>
#       <td>BB&amp;T and SunTrust have completed their merger, forming Truist enable, which we believe will drive the next step up in profitability for the franchises</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>69559a66</td>
#       <td>Considering Tulip's lack of profitability we do not believe the business maintains a cost advantage</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>745a44f4</td>
#       <td>TC Energy's profitability is not directly tied to commodity prices</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>824a897f</td>
#       <td>Wynn has recently renovated rooms and the gaming floor space at its peninsula property</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>63be7842</td>
#       <td>recently generated cash flows and our higher near-term outlook primarily for its tools used to diagnose and develop products to treat COVID-19</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.merge(label_ids, predictions, on='id')
pp(df.head())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>answers</th>
#       <th>question_type</th>
#       <th>prediction_text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>81c8921e</td>
#       <td>BB&amp;T and SunTrust have completed their merger, forming Truist, which we believe will drive the next step up in profitability for the franchises</td>
#       <td>enable</td>
#       <td>BB&amp;T and SunTrust have completed their merger, forming Truist enable, which we believe will drive the next step up in profitability for the franchises</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>69559a66</td>
#       <td>Given Tulip's lack of profitability (management has stated the business was not profitable at the time of the October 2019 acquisition), we do not believe the business maintains a cost advantage</td>
#       <td>enable</td>
#       <td>Considering Tulip's lack of profitability we do not believe the business maintains a cost advantage</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>745a44f4</td>
#       <td>TC Energy's profitability is not directly tied to commodity prices, because pipeline transportation costs are not tied to the price of natural gas and crude oil</td>
#       <td>cause</td>
#       <td>TC Energy's profitability is not directly tied to commodity prices</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>824a897f</td>
#       <td>Wynn has recently renovated rooms and the gaming floor space at its peninsula property, which should help the facility maintain market share over the next few years</td>
#       <td>enable</td>
#       <td>Wynn has recently renovated rooms and the gaming floor space at its peninsula property</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>63be7842</td>
#       <td>We are keeping our fair value estimate for Danaher at $160 per share after raising it in January 2021 to reflect recently generated cash flows and our higher near-term outlook primarily for its tools used to diagnose and develop products to treat COVID-19</td>
#       <td>cause</td>
#       <td>recently generated cash flows and our higher near-term outlook primarily for its tools used to diagnose and develop products to treat COVID-19</td>
#     </tr>
#   </tbody>
# </table>

# %%
pp(df.head(20))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>answers</th>
#       <th>question_type</th>
#       <th>prediction_text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>81c8921e</td>
#       <td>BB&amp;T and SunTrust have completed their merger, forming Truist, which we believe will drive the next step up in profitability for the franchises</td>
#       <td>enable</td>
#       <td>BB&amp;T and SunTrust have completed their merger, forming Truist enable, which we believe will drive the next step up in profitability for the franchises</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>69559a66</td>
#       <td>Given Tulip's lack of profitability (management has stated the business was not profitable at the time of the October 2019 acquisition), we do not believe the business maintains a cost advantage</td>
#       <td>enable</td>
#       <td>Considering Tulip's lack of profitability we do not believe the business maintains a cost advantage</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>745a44f4</td>
#       <td>TC Energy's profitability is not directly tied to commodity prices, because pipeline transportation costs are not tied to the price of natural gas and crude oil</td>
#       <td>cause</td>
#       <td>TC Energy's profitability is not directly tied to commodity prices</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>824a897f</td>
#       <td>Wynn has recently renovated rooms and the gaming floor space at its peninsula property, which should help the facility maintain market share over the next few years</td>
#       <td>enable</td>
#       <td>Wynn has recently renovated rooms and the gaming floor space at its peninsula property</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>63be7842</td>
#       <td>We are keeping our fair value estimate for Danaher at $160 per share after raising it in January 2021 to reflect recently generated cash flows and our higher near-term outlook primarily for its tools used to diagnose and develop products to treat COVID-19</td>
#       <td>cause</td>
#       <td>recently generated cash flows and our higher near-term outlook primarily for its tools used to diagnose and develop products to treat COVID-19</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6cd001cc</td>
#       <td>management will continue to pursue acquisition targets with high levels of recurring revenue, which would further lower the cyclicality of Fortive's portfolio</td>
#       <td>prevent</td>
#       <td>management will continue to pursue acquisition targets with high levels of recurring revenue</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>b55f3602</td>
#       <td>the 20% of consumers willing to adjust their habits to benefit the environment, as Beyond's products emit 90% less greenhouse gases, require 93% less land, 99% less water, and 46% less energy to produce</td>
#       <td>cause</td>
#       <td>Beyond's products emit 90% less greenhouse gases, require 93% less land, 99% less water, and 46% less energy to produce the 20% of consumers willing to adjust their habits to benefit the environment</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>ba04c014</td>
#       <td>a sudden departure occurred, we see Tesla's stock at risk for a severe decline</td>
#       <td>cause</td>
#       <td>a sudden departure occurred, cause Tesla's stock at risk for a severe decline</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>f31ae6c1</td>
#       <td>governments on national, state, and local levels reeling from budget problems and emergency expenses from COVID-19, the emergence of cannabis as a legal product has come to be viewed as a funding panacea</td>
#       <td>cause</td>
#       <td>emergence of cannabis as a legal product has come to be viewed as a funding panacea</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>8faa6a34</td>
#       <td>governments on national, state, and local levels reeling from budget problems and emergency expenses from COVID-19</td>
#       <td>cause</td>
#       <td>budget problems and emergency expenses from COVID-19 cause governments on national, state, and local levels reeling</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>08b86583</td>
#       <td>This is largely attributable to greater capital efficiency and business mix tilted toward credit cards. These high-yield loans drive the bank's exceptional net interest margins, which routinely exceed those of money center banks by 600 basis points</td>
#       <td>cause</td>
#       <td>This is attributable to greater capital efficiency and business mix tilted toward credit cards cause the bank's exceptional net interest margins, which routinely exceed those of money center banks by 600 basis points</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>90393ad4</td>
#       <td>its larger rivals (such as Royal Dutch Shell, BP, and Exxon) are vertically integrated, Valvoline does not enjoy the same degree of control over base oil supply</td>
#       <td>cause</td>
#       <td>Valvoline does not enjoy the same degree of control over base oil supply</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>081e721c</td>
#       <td>the economic impact from the COVID-19 pandemic will pressure earnings in 2020 due in large part to NiSource's high share of commercial and industrial customers</td>
#       <td>cause</td>
#       <td>NiSource's high share of commercial and industrial customers cause the economic impact from the COVID-19 pandemic will pressure earnings in 2020</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>53c9f734</td>
#       <td>evidence that Gap lacks a competitive edge, its operating margins and returns on invested capital have declined since 2013</td>
#       <td>enable</td>
#       <td>a competitive edge has declined since 2013 due to evidence that Gap lacks a competitive edge. its operating margins and returns on invested capital have declined since 2013</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>02b4d386</td>
#       <td>people start opting to use debit cards rather than credit cards, this could eat into Discover's ability to generate interest income</td>
#       <td>prevent</td>
#       <td>people start opting to use debit cards prevent Discover's ability to generate interest income</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>f4804946</td>
#       <td>licenses for these facilities are given by state and local officials, if ethylene oxide becomes a priority for state officials, Teleflex could face supply disruptions</td>
#       <td>cause</td>
#       <td>licenses for these facilities are given by state and local officials | ethylene oxide becomes a priority for state officials</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>f314f8a1</td>
#       <td>properties located in desirable submarkets with easy access to transportation, are near business districts, provide food and entertainment options, and have low crime statistics see higher demand</td>
#       <td>cause</td>
#       <td>properties located in desirable submarkets with easy access to transportation, are near business districts, provide food and entertainment options</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>36a02516</td>
#       <td>low crime statistics see higher demand that can translate to higher rents and higher growth</td>
#       <td>cause</td>
#       <td>low crime statistics see higher demand and higher growth</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>c0d04cdd</td>
#       <td>AMC's cable network business depends on advertising for about 35% of its revenue, the company could be vulnerable to a general slowdown in the economy or weak programming that reduces its viewership</td>
#       <td>cause</td>
#       <td>AMC's cable network business depends on advertising for about 35% of its revenue, cause the company could be vulnerable to a general slowdown in the economy or weak programming that reduces its viewership</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>916f30e5</td>
#       <td>We still view Polaris as more seasonally and end-user divers
